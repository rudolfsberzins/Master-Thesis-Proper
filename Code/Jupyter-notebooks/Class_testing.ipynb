# %%
from parse_and_prepare import ProteinProteinInteractionClassifier as ppi

# %%
files = ['MEDLINE_FILES',
         'drosophila_mentions',
         'drosophila_pairs_true',
         'fly_entities.tsv',
         '7227.protein.actions.v10.txt']
clf = ppi(files)

# %%
clf.prepare()

# %%
clf.produce_pairs()
# Out:
#  Producing Pairs DFs
#
# 1984
# (102316, 8)
# 102316
#
#
# (1903, 8)
# (1904, 8)
#
#
# BROKE
# 1903
#
#  Done with Pairs DFs
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:2440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
a = clf.pairs['SerialNo1'].tolist()
type(a[0])
# Out:
# int

# %%
files = ['data/MEDLINE_FILES',
         'data/output_mentions_yeast_1',
         'data/output_pairs_yeast_1',
         'data/yeast_entities.tsv',
         'data/4932.protein.actions.v10.txt']
clf_old = ppi_old(files)

# %%
a, b, c, d = clf_old.return_dfs()

# %%
z = clf_old.make_necessary_df()
# Out:
# Producing Pairs data frame
# Done with
# Done with
# Done with
# Done with
# Done with
# Something went wrong with
#  There was a  "['Text'] not in index" ! Ignoring it!
#
#  DONE with Pairs data frame production!
#
# Producing Pre BOW data frame
# Couldn't mask  Na(+)/H(+) antiporter  with RegEx
#  Trying a different way
# Couldn't mask  3-oxoacyl-[acyl-carrier-protein]-reductase  with RegEx
#  Trying a different way
#
#  Done with Pre Bow data frame
#
# produce_pairs = 38.09976816177368 seconds
# Producing BOW data frame
#
#  Done with Bag of Words data frame

# %%
import pickle

# %%
tests = pickle.load(open('gen_pairs_w_sen_df.pkl', 'rb'))

# %%
a = {}
for _, row in tests.iterrows():
    a.setdefault(row['Text'], []).append((row['Entity_name_x'], row['SerialNo_x'], row['Entity_name_y'], row['SerialNo_y']))

# %%
for key, val in a.items():
    if len(val) > 1:
        print (key, val)
# Out:
# The propionyl-lysine modification is introduced by bacterial Gcn-5-related N-acetyltransferase enzymes and can be removed by bacterial and human Sir2 enzymes (sirtuins). [('Gcn-5', 631431, 'N-acetyltransferase', 631390), ('Sir2', 629605, 'Gcn-5', 631431)]
# In association with the CDK Cdc28 it ensures hyphal development by phosphorylating the Cdc42 GAP Rga2, two septins and the transcription factor Efg1. [('Rga2', 630239, 'Cdc28', 629220), ('Efg1', 631451, 'Rga2', 630239)]
# The two pairs of duplicated genes happened to be heat shock genes (Ssa1/ Ssa2 and Ssb1/Ssb2), which have similar protein structures to each other, although the amino acid sequence identity between Ssa and Ssb is not high ( approximately 60%). [('Ssb1', 629802, 'Ssa2', 632822), ('Ssb2', 634117, 'Ssb1', 631519)]
# ...

# %%
tests_2 = pickle.load(open('both_ents_w_sen_df.pkl', 'rb'))

# %%
tests_3 = pickle.load(open('strict_pairs_w_sen_df.pkl', 'rb'))

# %%
tests.shape
# Out:
# (892, 5)

# %%
tests_3.shape
# Out:
# (440, 5)

# %%
len(test_dict.keys())
# Out:
# 722

# %%
tests_2.shape
# Out:
# (21859, 3)

# %%
test_dict2 = {row['Text']:[(row['Entity_name'], row['SerialNo'])] for _, row in tests_2.iterrows()}

# %%
len(test_dict2.keys())
# Out:
# 15068

# %%
a = tests_2['Text'].tolist()

# %%
len(a)
# Out:
# 15075

# %%
len(set(a))
# Out:
# 15068

# %%
s = tests[tests.isin(tests_3)]

# %%
a = (s != tests)

# %%
z = tests[a].dropna(axis = 0, how='any')

# %%
z
# Out:
#                    Entity_name_x  SerialNo_x               Entity_name_y  \
# 2                           HAP3    628939.0                        HAP2
# 3                           HAP2    631759.0                        HAP3
# 11                         dyn 1    632743.0                        Leu5
# 12                          Leu5    631542.0                       dyn 1
# 13                         dyn 1    632743.0                        Leu5
# 14                          Arg7    633602.0                       dyn 1
# 15                          Arg9    630424.0                        Arg7
# 16                         dyn 1    632743.0                        Arg9
# 21        glutathione peroxidase    634137.0                         GGT
# 22         glutathione reductase    635032.0  gamma-glutamyl transferase
# 24                         TAF-2    629495.0                       TAF-1
# 25                         TAF-1    631534.0                       TAF-2
# ...

# %%
for i in tests.loc[tests['SerialNo_x'] == 632184]['Text']:
    print (i)
# Out:
# DWs (95% CI) were 0 for mRS 0, 0.046 (0.004 to 0.088) for mRS 1, 0.212 (0.175 to 0.250) for mRS 2, 0.331 (0.292 to 0.371) for mRS 3, 0.652 (0.625 to 0.678) for mRS 4, 0.944 (0.873 to 1.015) for mRS 5, and 1.0 for mRS 6.
# Compared with mRS 0, there was a progressively higher independent risk for each of the study outcomes: stroke, mRS 1 (1.42, 0.97-2.08), mRS 2 (1.46, 0.97-2.20), mRS 3 (1.89, 1.20-2.97); major vascular events, mRS 1 (1.31, 1.01-1.70), mRS 2 (1.31, 0.99-1.74), mRS 3 (1.46, 1.06-2.01); and all-cause death, mRS 1 (1.75, 1.03-2.98), mRS 2 (2.49, 1.44-4.31), mRS 3 (2.72, 1.43-5.19).
# Compared with mRS 0, there was a progressively higher independent risk for each of the study outcomes: stroke, mRS 1 (1.42, 0.97-2.08), mRS 2 (1.46, 0.97-2.20), mRS 3 (1.89, 1.20-2.97); major vascular events, mRS 1 (1.31, 1.01-1.70), mRS 2 (1.31, 0.99-1.74), mRS 3 (1.46, 1.06-2.01); and all-cause death, mRS 1 (1.75, 1.03-2.98), mRS 2 (2.49, 1.44-4.31), mRS 3 (2.72, 1.43-5.19).

# %%
test_dict['Compared with mRS 0, there was a progressively higher independent risk for each of the study outcomes: stroke, mRS 1 (1.42, 0.97-2.08), mRS 2 (1.46, 0.97-2.20), mRS 3 (1.89, 1.20-2.97); major vascular events, mRS 1 (1.31, 1.01-1.70), mRS 2 (1.31, 0.99-1.74), mRS 3 (1.46, 1.06-2.01); and all-cause death, mRS 1 (1.75, 1.03-2.98), mRS 2 (2.49, 1.44-4.31), mRS 3 (2.72, 1.43-5.19).']
# Out:
# [('mRS 3', 632184, 'mRS 1', 632020)]

# %%
 1265189, 1265189, 1265189, 1265189, 1265189, 1265189, 1265189, 1265193, 1265193, 1265274, 1265274, 1265274, 1265274, 1265274, 1265274, 1265274, 1265274, 1265292, 1265292, 1265292, 1265292, 1265292, 1265292, 1265292, 1265292, 1265292, 1265292, 1265292, 1265311, 1265311, 1265311, 1265311, 1265326, 1265326, 1265326, 1265346, 1265358, 1265358, 1265358, 1265358, 1265358, 1265358, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265359, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265408, 1265410, 1265410, 1265410, 1265410, 1265410, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265419, 1265421, 1265425, 1265425, 1265452, 1265452, 1265452, 1265452, 1265452, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265467, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265478, 1265492, 1265492, 1265492, 1265492, 1265492, 1265492, 1265492, 1265539, 1265551, 1265551, 1265554, 100001463, 100001463, 100001463, 100001463, 100001463, 100001463, 100001463, 100001463, 100001463, 100024658, 100024658, 100024658, 100024658, 100024658, 100024658, 100024658, 100089024, 100089024, 100089024, 100089024, 100089024, 100089024, 100089024, 100089024, 100089024]

# %%
for item in a:
    if item in clf.pairs['SerialNo1'].tolist():
        print (item)
    if '2116123' in clf.pairs['SerialNo2'].tolist():
        print (item)

# %%
import pickle

# %%
import prediction as pred
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
rat_train_data = pickle.load(open('Results/rat/rat_strict_real_be_mod_train_data.pkl', 'rb'))
rat_test_data = pickle.load(open('Results/rat/rat_strict_real_be_mod_test_data.pkl', 'rb'))
rat_train_labels = pickle.load(open('Results/rat/rat_strict_real_be_mod_train_labels.pkl', 'rb'))
rat_test_labels = pickle.load(open('Results/rat/rat_strict_real_be_mod_test_labels.pkl', 'rb'))

# %%
len(rat_train_data)
# Out:
# 12403

# %%
import pickle

# %%
a = pickle.load(open('Results/drosophila/gen_real.pkl', 'rb'))

# %%
a
# Out:
# {'It has long been known that the conventional  and beta subunits form heterodimeric enzymes that are potently activated by , but do not bind O2.': [['NO',
#    'FBpp0112131',
#    'sGC alpha',
#    'FBpp0084819']],
#  'These findings, together with the observation that  and  could interact directly with Msk, suggest their direct involvement in the nuclear import of MAD.': [['Nup93',
#    'FBpp0073659',
#    'Sec13',
#    'FBpp0083801']],
#  'Although  have not been molecularly identified, transient receptor potential (TRP) channels share a number of operational parameters with .': [['SOCs',
#    'FBpp0302960',
#    'inositol 1,4,5-trisphosphate receptor',
#    'FBpp0078336']],
#  'We also show that knockdown of  leads to lower levels of egg laying, higher rates of sexual receptivity to subsequent males, and abnormal sperm usage patterns, processes that are independent of .': [['CG11864',
#    'FBpp0080342',
#    'CG10586',
#    'FBpp0077991']],
# ...

# %%
import pandas as pd
x00 = pickle.load(open('Results/x00_strict_pairs_w_sen_df.pkl', 'rb'))
x01 = pickle.load(open('Results/x01_strict_pairs_w_sen_df.pkl', 'rb'))

x00.to_csv('Results/x00_strict_pairs_df.tsv', sep='\t', index=False)
x01.to_csv('Results/x01_strict_pairs_df.tsv', sep='\t', index=False)

# %%
test = pd.read_csv('test', sep='\t', names=['PMID', 'Para', 'Sen', 'Char_St', 'Char_End', 'Text', 'Ent_ID', 'Real_ID'])

# %%
test
# Out:
#            PMID  Para  Sen  Char_St  Char_End     Text  Ent_ID  Real_ID
# 0      25492134     2    7     1520      1526  insulin    9606  1846771
# 1      25493642     2    5     1116      1122  insulin    9606  1846771
# 2      25525634     2    5     1070      1076  insulin    9606  1846771
# 3      25533134     1    1       46        52  insulin    9606  1846771
# 4      25533134     2    1      138       144  insulin    9606  1846771
# 5      25533134     2    1      207       213  insulin    9606  1846771
# 6      25533134     2    5      833       839  insulin    9606  1846771
# 7      25533134     2    5      917       923  insulin    9606  1846771
# 8      25533134     2    6     1170      1176  insulin    9606  1846771
# 9      25533134     2   10     1743      1749  insulin    9606  1846771
# 10     25536563     2   10     1705      1710   leptin    9606  1846843
# 11     25536990     2    4      744       750  insulin    9606  1846771
# ...

# %%
iterator = test.iterrows()
_, last = iterator.__next__()
test_list = []
for idx, row in iterator:
    if row["PMID"] == last["PMID"] and row["Para"] == last["Para"] and row["Sen"] == last["Sen"] and row["Text"] != last["Text"] and row["Real_ID"] != last["Real_ID"]:
        test_list.append(row['PMID'])
    last = row

# %%
strict_dros_bf = pickle.load(open('Results/dros_testing/drosophila_mentions_strict_real.pkl', 'rb'))
strict_dros_af = pickle.load(open('Results/drosophila_mentions_strict_real.pkl', 'rb'))
gen_dros_bf = pickle.load(open('Results/dros_testing/drosophila_mentions_gen_real.pkl', 'rb'))
gen_dros_af = pickle.load(open('Results/drosophila_mentions_gen_real.pkl', 'rb'))
be_dros_bf = pickle.load(open('Results/dros_testing/drosophila_mentions_be_real.pkl', 'rb'))
be_dros_af = pickle.load(open('Results/drosophila_mentions_be_real.pkl', 'rb'))

# %%
print('Before - ', len(strict_dros_bf), ' After - ', len(strict_dros_af), 'Drop - ', 1-(len(strict_dros_af)/len(strict_dros_bf)))
print('Before - ', len(gen_dros_bf), ' After - ', len(gen_dros_af), 'Drop - ', 1-(len(gen_dros_af)/len(gen_dros_bf)))
print('Before - ', len(be_dros_bf), ' After - ', len(be_dros_af), 'Drop - ', 1-(len(be_dros_af)/len(be_dros_bf)))
# Out:
# Before -  34  After -  31 Drop -  0.08823529411764708
# Before -  202  After -  184 Drop -  0.08910891089108908
# Before -  987  After -  837 Drop -  0.15197568389057747

# %%
files = ['MEDLINE_FILES',
         'drosophila_mentions',
         'fly_entities.tsv',
         '7227.protein.actions.v10.txt']


clf = ppi(files)
clf.prepare()

# %%
both_entries = clf.mentions.sort_values('PMID')
true_pairs = clf.extract_true_pairs(both_entries)
# Out:
# (383405, 8)
# (383406, 8)
#
#
# BROKE
# 383405

# %%
import re
import glob
import gzip
import csv
import os
import time
import sys
import pickle
import logging
import file_readers as fr
import pandas as pd
from nltk.tokenize import sent_tokenize

# %%
def yield_corpus_names():
        """Produces MEDLINE abstract gzip filenames"""
        for filename in glob.glob(os.path.join(clf.medline_folder, '*.tsv.gz')):
            yield filename

def yield_abstract_corpus():
    """Yields a single abstract line"""
    for path in yield_corpus_names():
        with gzip.open(path, 'rt', encoding='utf-8') as corpus:
            tsv_reader = csv.reader(corpus, delimiter='\t')
            for row in tsv_reader:
                yield row

# %%
def get_b2c_mapping(document):
    # get byte to character mapping for document
    u_results = []
    # for each byte in the document, determine if it belongs to a multi byte character
    mapping = {} # byte to char
    byte = 0
    character = 0
#     u_document = document.decode("utf-8") # turn bytes into characters
    for b in document:
        u = b.encode('utf-8') # back to bytes
        char_bytes = len(u) # how many bytes does this character consist of
        for i in range(0, char_bytes):
            mapping[byte+i] = character
        byte += char_bytes
        character += 1  
    return mapping

# %%
index = 0
for row in yield_abstract_corpus():
    text_of_interest = row[4] + row[5]
    mapping = get_b2c_mapping(text_of_interest)
    hit = re.findall('PMID:\d*', row[0])[0][5:]
    temp_hits = true_pairs.loc[(true_pairs['PMID'] == int(hit)), ['Char_Start_x']]
    if len(temp_hits) != 0:
        temp_hit_list = list(temp_hits['Char_Start_x'])
        mapped_hit_list = []
        for hit in temp_hit_list:
            hit = mapping[int(hit)]
            mapped_hit_list.append(hit)
        if temp_hit_list != mapped_hit_list:
            print(temp_hit_list, mapped_hit_list, hit)
            index += 1
            if index == 10:
                break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-7321d8a514c7> in <module>()
#       1 index = 0
#       2 for row in yield_abstract_corpus():
# ----> 3     text_of_interest = row[4] + row[5]
#       4     mapping = get_b2c_mapping(text_of_interest)
#       5     hit = re.findall('PMID:\d*', row[0])[0][5:]
#
# IndexError: list index out of range

# %%
mapping = get_b2c_mapping('Jānis Bērziņš! ')

# %%
print (mapping)
# Out:
# {0: 0, 1: 1, 2: 1, 3: 2, 4: 3, 5: 4, 6: 5, 7: 6, 8: 7, 9: 7, 10: 8, 11: 9, 12: 10, 13: 11, 14: 11, 15: 12, 16: 12, 17: 13, 18: 14}

# %%
for key, val in mapping.items():
    if key != val:
        print(key, val)
# Out:
# 2 1
# 3 2
# 4 3
# 5 4
# 6 5
# 7 6
# 8 7
# 9 7
# 10 8
# 11 9
# 12 10
# 13 11
# 14 11
# 15 12
# 16 12
